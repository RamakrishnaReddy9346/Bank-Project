# %% [markdown]
# # Predictive Analytics for Retail Banking

# %% [markdown]
# **Abstract: The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit (variable y).**

# %% [markdown]
# The data is from a marketing campaign designed to pick customers with a higher than normal propensity to uptake a term deposit offer.  A term deposit is a deposit that a financial institution offers with a high fixed rate and a fixed maturity date.  There are two datasets that we investigated:
#
# The smallest dataset is provided to test more computationally demanding machine learning algorithms (e.g. SVM). The classification goal is to predict if the client will subscribe a term deposit (variable y).
#
# There are 16 input variables:
#
# **Client data:**
# 1.   age (*numeric*)
# 2.   job : type of job (*categorical*: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student", "blue-collar","self-employed","retired","technician","services")
# 3.   marital : marital status (*categorical*: "married","divorced","single"; note: "divorced" means divorced or widowed)
# 4.   education (*categorical*: "unknown","secondary","primary","tertiary")
# 5.   default: has credit in default? (*binary*: "yes","no")
# 6.   balance: average yearly balance, in euros (*numeric*)
# 7.   housing: has housing loan? (*binary*: "yes","no")
# 8.   loan: has personal loan? (*binary*: "yes","no")
#
# **Campaign data:**
#
# 9.   contact: contact communication type (*categorical*: "unknown","telephone","cellular")
# 10.   day: last contact day of the month (*numeric*)
# 11.   month: last contact month of year (*categorical*: "jan", "feb", "mar", ..., "nov", "dec")
# 12.   duration: last contact duration, in seconds (*numeric*)
#
# **Other attributes:**
#
# 13.   campaign: number of contacts performed during this campaign and for this client (*numeric*, includes last contact)
# 14.   pdays: number of days that passed by after the client was last contacted from a previous campaign (*numeric*: -1 means client was not previously contacted)
# 15.   previous: (*numeric*: number of contacts performed before this campaign and for this client)
# 16.   poutcome: outcome of the previous marketing campaign (*categorical*: "unknown","other","failure","success")
#
# **Target variable:**
#
# 17.   deposite - has the client subscribed a term deposit? (*binary*: "yes","no")

# %%
#import pacakges
import numpy as np
import pandas as pd

# %%
#read data
data=pd.read_csv('bank.csv')

# %% [markdown]
# # Basic check

# %%
data.head()
# Out:
#    age         job  marital  education fault  balance housing loan  contact  \
# 0   59      admin.  married  secondary    no     2343     yes   no  unknown
# 1   59      admin.  married  secondary    no     2343     yes   no  unknown
# 2   56      admin.  married  secondary    no       45      no   no  unknown
# 3   41  technician  married  secondary    no     1270     yes   no  unknown
# 4   55    services  married  secondary    no     2476     yes   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1042         1     -1         0  unknown     yes
# 2    5   may      1467         1     -1         0      NaN     yes
# 3    5   may      1389         1     -1         0  unknown     yes
# 4    5   may       579         1     -1         0  unknown     yes

# %%
# check total rows and columns in data
data.shape
# Out:
# (11163, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11163 entries, 0 to 11162
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11163 non-null  int64
#  1   job        11163 non-null  object
#  2   marital    11163 non-null  object
#  3   education  11163 non-null  object
#  4   fault      11163 non-null  object
#  5   balance    11163 non-null  int64
#  6   housing    11163 non-null  object
#  7   loan       11163 non-null  object
#  8   contact    11163 non-null  object
#  9   day        11163 non-null  int64
#  10  month      11163 non-null  object
#  11  duration   11163 non-null  int64
#  12  campaign   11163 non-null  int64
#  13  pdays      11163 non-null  int64
#  14  previous   11163 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11163 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11163.000000  11163.000000  11163.000000  11163.000000  11163.000000
# mean      41.233539   1528.611484     15.657081    372.053839      2.508286
# std       11.914022   3225.278053      8.420967    347.170757      2.721993
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.500000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11163.000000  11163.000000
# mean      51.325719      0.832482
# std      108.754538      2.291918
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.500000      1.000000
# max      854.000000     58.000000

# %%
## check for duplicates
duplicateRows=data[data.duplicated(keep='last')]

# %%
data.drop_duplicates(keep='last',inplace=True)

# %%
# null value check
data.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# fault        0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     1
# deposit      0
# dtype: int64

# %%
len(data.index)
# Out:
# 11162

# %%
# null value check
round(100*data.isna().sum()/len(data.index),2)
# Out:
# age          0.00
# job          0.00
# marital      0.00
# education    0.00
# fault        0.00
# balance      0.00
# housing      0.00
# loan         0.00
# contact      0.00
# day          0.00
# month        0.00
# duration     0.00
# campaign     0.00
# pdays        0.00
# previous     0.00
# poutcome     0.01
# deposit      0.00
# dtype: float64

# %%
# drop null value
data.dropna(subset=['poutcome'],inplace=True)

# %%
data.head()
# Out:
#    age         job  marital  education fault  balance housing loan  contact  \
# 1   59      admin.  married  secondary    no     2343     yes   no  unknown
# 3   41  technician  married  secondary    no     1270     yes   no  unknown
# 4   55    services  married  secondary    no     2476     yes   no  unknown
# 5   54      admin.  married   tertiary    no      184      no   no  unknown
# 6   42  management   single   tertiary    no        0     yes  yes  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 1    5   may      1042         1     -1         0  unknown     yes
# 3    5   may      1389         1     -1         0  unknown     yes
# 4    5   may       579         1     -1         0  unknown     yes
# 5    5   may       673         2     -1         0  unknown     yes
# 6    5   may       562         2     -1         0  unknown     yes

# %% [markdown]
# # Outlier Detection

# %%
numerics=['int64']
outlier_chk_features=data.select_dtypes(include=numerics)

# %%
data.describe(percentiles=[.25,.50,.80,.90])
# Out:
#                 age       balance           day      duration      campaign  \
# count  11161.000000  11161.000000  11161.000000  11161.000000  11161.000000
# mean      41.230624   1528.671445     15.658991    371.895708      2.508557
# std       11.913083   3225.527257      8.420512    346.989140      2.722162
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 80%       52.000000   2223.000000     24.000000    585.000000      3.000000
# 90%       58.000000   3899.000000     28.000000    838.000000      5.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11161.000000  11161.000000
# mean      51.335095      0.832631
# std      108.762026      2.292096
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 80%       95.000000      1.000000
# 90%      191.000000      3.000000
# max      854.000000     58.000000

# %% [markdown]
# ### Examine categorical data

# %%
data.nunique()
# Out:
# age            76
# job            12
# marital         3
# education       4
# fault           2
# balance      3805
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1428
# campaign       36
# pdays         472
# previous       34
# poutcome        4
# deposit         2
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11161 entries, 1 to 11162
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11161 non-null  int64
#  1   job        11161 non-null  object
#  2   marital    11161 non-null  object
#  3   education  11161 non-null  object
#  4   fault      11161 non-null  object
#  5   balance    11161 non-null  int64
#  6   housing    11161 non-null  object
#  7   loan       11161 non-null  object
#  8   contact    11161 non-null  object
#  9   day        11161 non-null  int64
#  10  month      11161 non-null  object
#  11  duration   11161 non-null  int64
#  12  campaign   11161 non-null  int64
#  13  pdays      11161 non-null  int64
#  14  previous   11161 non-null  int64
#  15  poutcome   11161 non-null  object
#  16  deposit    11161 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.5+ MB

# %%
data.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.112360 -0.000622 -0.000161 -0.005217  0.002828  0.020210
# balance   0.112360  1.000000  0.010416  0.022576 -0.013917  0.017392  0.030791
# day      -0.000622  0.010416  1.000000 -0.018163  0.136956 -0.077293 -0.059026
# duration -0.000161  0.022576 -0.018163  1.000000 -0.041420 -0.027268 -0.026626
# campaign -0.005217 -0.013917  0.136956 -0.041420  1.000000 -0.102752 -0.049719
# pdays     0.002828  0.017392 -0.077293 -0.027268 -0.102752  1.000000  0.507264
# previous  0.020210  0.030791 -0.059026 -0.026626 -0.049719  0.507264  1.000000

# %%
# examine unique values
objcol=['job','marital','education','housing']
for col in objcol:
    print(col, '\n' ,data[col].unique())
# Out:
# job
#  ['admin.' 'technician' 'services' 'management' 'retired' 'blue-collar'
#  'unemployed' 'entrepreneur' 'housemaid' 'unknown' 'self-employed'
#  'student']
# marital
#  ['married' 'single' 'divorced']
# education
#  ['secondary' 'tertiary' 'primary' 'unknown']
# housing
#  ['yes' 'no']

# %%
data.nunique()
# Out:
# age            76
# job            12
# marital         3
# education       4
# fault           2
# balance      3805
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1428
# campaign       36
# pdays         472
# previous       34
# poutcome        4
# deposit         2
# dtype: int64

# %%
data.head()
# Out:
#    age         job  marital  education fault  balance housing loan  contact  \
# 1   59      admin.  married  secondary    no     2343     yes   no  unknown
# 3   41  technician  married  secondary    no     1270     yes   no  unknown
# 4   55    services  married  secondary    no     2476     yes   no  unknown
# 5   54      admin.  married   tertiary    no      184      no   no  unknown
# 6   42  management   single   tertiary    no        0     yes  yes  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 1    5   may      1042         1     -1         0  unknown     yes
# 3    5   may      1389         1     -1         0  unknown     yes
# 4    5   may       579         1     -1         0  unknown     yes
# 5    5   may       673         2     -1         0  unknown     yes
# 6    5   may       562         2     -1         0  unknown     yes

# %% [markdown]
# # Data Visulazation

# %%
# scatter plot
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(data['age'],data['duration'])

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
# heatmap with values
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# bar chart
plt.figure(figsize=(10,5))
sns.countplot(x='contact',hue='deposit',data=data)
plt.title('Bar chart for Contact and Deposite')
# Out:
# Text(0.5, 1.0, 'Bar chart for Contact and Deposite')

# %% [markdown]
# # feature enginerring

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11161 entries, 1 to 11162
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11161 non-null  int64
#  1   job        11161 non-null  object
#  2   marital    11161 non-null  object
#  3   education  11161 non-null  object
#  4   fault      11161 non-null  object
#  5   balance    11161 non-null  int64
#  6   housing    11161 non-null  object
#  7   loan       11161 non-null  object
#  8   contact    11161 non-null  object
#  9   day        11161 non-null  int64
#  10  month      11161 non-null  object
#  11  duration   11161 non-null  int64
#  12  campaign   11161 non-null  int64
#  13  pdays      11161 non-null  int64
#  14  previous   11161 non-null  int64
#  15  poutcome   11161 non-null  object
#  16  deposit    11161 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.5+ MB

# %%
objcol=data.select_dtypes(include=['object']).columns.tolist()
for col in objcol:
    print(col, '\n' ,data[col].unique())
# Out:
# job
#  ['admin.' 'technician' 'services' 'management' 'retired' 'blue-collar'
#  'unemployed' 'entrepreneur' 'housemaid' 'unknown' 'self-employed'
#  'student']
# marital
#  ['married' 'single' 'divorced']
# education
#  ['secondary' 'tertiary' 'primary' 'unknown']
# fault
#  ['no' 'yes']
# housing
#  ['yes' 'no']
# loan
#  ['no' 'yes']
# contact
#  ['unknown' 'cellular' 'telephone']
# month
#  ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# poutcome
#  ['unknown' 'other' 'failure' 'success']
# deposit
#  ['yes' 'no']

# %%
# convert binary category to numbers
data['fault'].replace(['yes','no'],[1,0],inplace=True)
data['housing'].replace(['yes','no'],[1,0],inplace=True)
data['loan'].replace(['yes','no'],[1,0],inplace=True)
data['deposit'].replace(['yes','no'],[1,0],inplace=True)

# %%
for col in ['fault','housing','loan','deposit']:
    data[col].replace(['yes','no'],[1,0],inplace=True)

# %%
data.head()
# Out:
#    age         job  marital  education  fault  balance  housing  loan  \
# 1   59      admin.  married  secondary      0     2343        1     0
# 3   41  technician  married  secondary      0     1270        1     0
# 4   55    services  married  secondary      0     2476        1     0
# 5   54      admin.  married   tertiary      0      184        0     0
# 6   42  management   single   tertiary      0        0        1     1
#
#    contact  day month  duration  campaign  pdays  previous poutcome  deposit
# 1  unknown    5   may      1042         1     -1         0  unknown        1
# 3  unknown    5   may      1389         1     -1         0  unknown        1
# 4  unknown    5   may       579         1     -1         0  unknown        1
# 5  unknown    5   may       673         2     -1         0  unknown        1
# 6  unknown    5   may       562         2     -1         0  unknown        1

# %%
# label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.iloc[:,1]=le.fit_transform(data.iloc[:,1])
data.iloc[:,2]=le.fit_transform(data.iloc[:,2])
data.iloc[:,3]=le.fit_transform(data.iloc[:,3])
data.iloc[:,8]=le.fit_transform(data.iloc[:,8])
data.iloc[:,10]=le.fit_transform(data.iloc[:,10])
data.iloc[:,15]=le.fit_transform(data.iloc[:,15])

# %%
data.head()
# Out:
#    age  job  marital  education  fault  balance  housing  loan  contact  day  \
# 1   59    0        1          1      0     2343        1     0        2    5
# 3   41    9        1          1      0     1270        1     0        2    5
# 4   55    7        1          1      0     2476        1     0        2    5
# 5   54    0        1          2      0      184        0     0        2    5
# 6   42    4        2          2      0        0        1     1        2    5
#
#    month  duration  campaign  pdays  previous  poutcome  deposit
# 1      8      1042         1     -1         0         3        1
# 3      8      1389         1     -1         0         3        1
# 4      8       579         1     -1         0         3        1
# 5      8       673         2     -1         0         3        1
# 6      8       562         2     -1         0         3        1

# %%
X=data.drop(columns='deposit')
Y=data['deposit']

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()
X_min_max=pd.DataFrame(min_max.fit_transform(X),columns=X.columns)

# %%
X_min_max.head()
# Out:
#         age       job  marital  education  fault   balance  housing  loan  \
# 0  0.532468  0.000000      0.5   0.333333    0.0  0.104371      1.0   0.0
# 1  0.298701  0.818182      0.5   0.333333    0.0  0.092185      1.0   0.0
# 2  0.480519  0.636364      0.5   0.333333    0.0  0.105882      1.0   0.0
# 3  0.467532  0.000000      0.5   0.666667    0.0  0.079851      0.0   0.0
# 4  0.311688  0.363636      1.0   0.666667    0.0  0.077762      1.0   1.0
#
#    contact       day     month  duration  campaign  pdays  previous  poutcome
# 0      1.0  0.133333  0.727273  0.268110  0.000000    0.0       0.0       1.0
# 1      1.0  0.133333  0.727273  0.357566  0.000000    0.0       0.0       1.0
# 2      1.0  0.133333  0.727273  0.148750  0.000000    0.0       0.0       1.0
# 3      1.0  0.133333  0.727273  0.172983  0.016129    0.0       0.0       1.0
# 4      1.0  0.133333  0.727273  0.144367  0.016129    0.0       0.0       1.0

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train.shape
# Out:
# (7812, 16)

# %%
X_test.shape
# Out:
# (3349, 16)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# make the prediction
y_pred=lr.predict(X_test)

# %%
print(y_pred)
# Out:
# [0 1 1 ... 1 0 0]

# %%
print(Y_test.values)
# Out:
# [0 1 1 ... 1 0 0]

# %%
lr.score(X_test,Y_test)
# Out:
# 0.7670946551209317

# %%
# Accuracy check
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_pred,Y_test)*100
# Out:
# 76.70946551209316

# %%
confusion_matrix(y_pred,Y_test)
# Out:
# array([[1465,  440],
#        [ 340, 1104]], dtype=int64)

# %%
X_test.head()
# Out:
#       age  job  marital  education  fault  balance  housing  loan  contact  \
# 7069   25    0        2          2      0      220        0     0        0
# 1790   59    5        0          1      0      514        0     0        0
# 3702   57    5        1          1      0     1044        0     0        1
# 6301   49    1        0          1      0       23        0     0        0
# 4747   49    2        1          1      0      687        1     0        0
#
#       day  month  duration  campaign  pdays  previous  poutcome
# 7069   26      8        68         1     -1         0         3
# 1790    4      8       673         6     90         1         2
# 3702   12      5       567         1    182         3         2
# 6301   17      9       221         2     -1         0         3
# 4747   17      0       772         1     -1         0         3

# %% [markdown]
# ## KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=knn.predict(X_test)

# %%
accuracy_score(y_pred,Y_test)*100
# Out:
# 73.63392057330546

# %%
confusion_matrix(y_pred,Y_test)
# Out:
# array([[1372,  450],
#        [ 433, 1094]], dtype=int64)

# %% [markdown]
# ## Support vector machine

# %%
from sklearn.svm import SVC
svm=SVC(kernel='sigmoid')

# %%
svm.fit(X_train,Y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred=svm.predict(X_test)

# %%
accuracy_score(y_pred,Y_test)*100
# Out:
# 50.851000298596595

# %%
confusion_matrix(y_pred,Y_test)
# Out:
# array([[988, 829],
#        [817, 715]], dtype=int64)

# %% [markdown]
# # Decision Tree

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt_clf=DecisionTreeClassifier()
dt_clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt_clf.predict(X_test)

# %%
accuracy_score(y_pred,Y_test)*100
# Out:
# 78.76978202448493

# %%
from sklearn import tree
tree.plot_tree(dt_clf,filled=True)
# Out:
# [Text(0.41196955901081217, 0.9827586206896551, 'X[11] <= 206.5\ngini = 0.499\nsamples = 7812\nvalue = [4068, 3744]'),
#  Text(0.14012535856238464, 0.9482758620689655, 'X[11] <= 129.5\ngini = 0.331\nsamples = 3143\nvalue = [2486, 657]'),
#  Text(0.05633524424787462, 0.9137931034482759, 'X[10] <= 9.5\ngini = 0.177\nsamples = 1735\nvalue = [1565, 170]'),
#  Text(0.027610130888270353, 0.8793103448275862, 'X[11] <= 79.5\ngini = 0.155\nsamples = 1676\nvalue = [1534, 142]'),
#  Text(0.016681541766254197, 0.8448275862068966, 'X[13] <= 373.5\ngini = 0.052\nsamples = 793\nvalue = [772, 21]'),
#  Text(0.013364898798898739, 0.8103448275862069, 'X[5] <= 9279.0\ngini = 0.042\nsamples = 787\nvalue = [770, 17]'),
#  Text(0.009636039088736273, 0.7758620689655172, 'X[10] <= 0.5\ngini = 0.036\nsamples = 770\nvalue = [756, 14]'),
#  Text(0.005082745892959792, 0.7413793103448276, 'X[11] <= 75.0\ngini = 0.18\nsamples = 30\nvalue = [27, 3]'),
#  Text(0.0041146038181103075, 0.7068965517241379, 'X[0] <= 29.5\ngini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(0.0031464617432608237, 0.6724137931034483, 'X[5] <= 1246.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0021783196684113395, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0041146038181103075, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.005082745892959792, 0.6724137931034483, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.006050887967809276, 0.7068965517241379, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.014189332284512753, 0.7413793103448276, 'X[0] <= 60.5\ngini = 0.029\nsamples = 740\nvalue = [729, 11]'),
#  Text(0.010831089462378604, 0.7068965517241379, 'X[0] <= 23.5\ngini = 0.027\nsamples = 736\nvalue = [726, 10]'),
#  Text(0.00701903004265876, 0.6724137931034483, 'X[1] <= 9.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.006050887967809276, 0.6379310344827587, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.007987172117508245, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014643148882098448, 0.6724137931034483, 'X[9] <= 13.5\ngini = 0.024\nsamples = 730\nvalue = [721, 9]'),
#  Text(0.009923456267207212, 0.6379310344827587, 'X[10] <= 5.5\ngini = 0.059\nsamples = 232\nvalue = [225, 7]'),
#  Text(0.006292923486521647, 0.603448275862069, 'X[9] <= 9.5\ngini = 0.142\nsamples = 78\nvalue = [72, 6]'),
#  Text(0.003872568299397937, 0.5689655172413793, 'X[0] <= 27.5\ngini = 0.062\nsamples = 62\nvalue = [60, 2]'),
#  Text(0.0019362841496989684, 0.5344827586206896, 'X[9] <= 8.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0009681420748494842, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0029044262245484526, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.005808852449096905, 0.5344827586206896, 'X[11] <= 70.5\ngini = 0.033\nsamples = 59\nvalue = [58, 1]'),
#  Text(0.004840710374247421, 0.5, 'gini = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(0.0067769945239463895, 0.5, 'X[11] <= 71.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.005808852449096905, 0.46551724137931033, 'X[0] <= 35.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.004840710374247421, 0.43103448275862066, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0067769945239463895, 0.43103448275862066, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.007745136598795874, 0.46551724137931033, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.008713278673645358, 0.5689655172413793, 'X[10] <= 2.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.007745136598795874, 0.5344827586206896, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.009681420748494842, 0.5344827586206896, 'X[5] <= 114.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.008713278673645358, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.010649562823344326, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.013553989047892779, 0.603448275862069, 'X[0] <= 32.5\ngini = 0.013\nsamples = 154\nvalue = [153, 1]'),
#  Text(0.012585846973043295, 0.5689655172413793, 'X[0] <= 31.5\ngini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(0.01161770489819381, 0.5344827586206896, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.013553989047892779, 0.5344827586206896, 'X[10] <= 7.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.012585846973043295, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014522131122742263, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.014522131122742263, 0.5689655172413793, 'gini = 0.0\nsamples = 120\nvalue = [120, 0]'),
#  Text(0.019362841496989684, 0.6379310344827587, 'X[13] <= 356.5\ngini = 0.008\nsamples = 498\nvalue = [496, 2]'),
#  Text(0.017426557347290716, 0.603448275862069, 'X[0] <= 28.5\ngini = 0.004\nsamples = 493\nvalue = [492, 1]'),
#  Text(0.01645841527244123, 0.5689655172413793, 'X[10] <= 3.5\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(0.015490273197591747, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.017426557347290716, 0.5344827586206896, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.018394699422140198, 0.5689655172413793, 'gini = 0.0\nsamples = 460\nvalue = [460, 0]'),
#  Text(0.021299125646688653, 0.603448275862069, 'X[9] <= 17.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.020330983571839167, 0.5689655172413793, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.022267267721538135, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0175475751066469, 0.7068965517241379, 'X[14] <= 5.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.016579433031797416, 0.6724137931034483, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.018515717181496385, 0.6724137931034483, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.017093758509061203, 0.7758620689655172, 'X[9] <= 12.0\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.01612561643421172, 0.7413793103448276, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.01806190058391069, 0.7413793103448276, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.019998184733609658, 0.8103448275862069, 'X[11] <= 21.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.019030042658760172, 0.7758620689655172, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.02096632680845914, 0.7758620689655172, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.038538720010286506, 0.8448275862068966, 'X[0] <= 26.5\ngini = 0.237\nsamples = 883\nvalue = [762, 121]'),
#  Text(0.02532296614528182, 0.8103448275862069, 'X[6] <= 0.5\ngini = 0.5\nsamples = 41\nvalue = [21, 20]'),
#  Text(0.02290261095815811, 0.7758620689655172, 'X[9] <= 4.5\ngini = 0.393\nsamples = 26\nvalue = [7, 19]'),
#  Text(0.02096632680845914, 0.7413793103448276, 'X[5] <= 2745.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.019998184733609658, 0.7068965517241379, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.021934468883308626, 0.7068965517241379, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.024838895107857077, 0.7413793103448276, 'X[15] <= 1.5\ngini = 0.245\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.023870753033007595, 0.7068965517241379, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.025807037182706563, 0.7068965517241379, 'X[7] <= 0.5\ngini = 0.18\nsamples = 20\nvalue = [2, 18]'),
#  Text(0.024838895107857077, 0.6724137931034483, 'X[1] <= 8.5\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.023870753033007595, 0.6379310344827587, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.025807037182706563, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.026775179257556046, 0.6724137931034483, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.02774332133240553, 0.7758620689655172, 'X[11] <= 121.0\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.026775179257556046, 0.7413793103448276, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.028711463407255014, 0.7413793103448276, 'X[8] <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.02774332133240553, 0.7068965517241379, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0296796054821045, 0.7068965517241379, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.051754473875291196, 0.8103448275862069, 'X[15] <= 2.5\ngini = 0.211\nsamples = 842\nvalue = [741, 101]'),
#  Text(0.03857441079478414, 0.7758620689655172, 'X[15] <= 1.5\ngini = 0.372\nsamples = 162\nvalue = [122, 40]'),
#  Text(0.03367319154085862, 0.7413793103448276, 'X[8] <= 1.5\ngini = 0.257\nsamples = 132\nvalue = [112, 20]'),
#  Text(0.032705049466009134, 0.7068965517241379, 'X[13] <= 108.5\ngini = 0.239\nsamples = 130\nvalue = [112, 18]'),
#  Text(0.028711463407255014, 0.6724137931034483, 'X[12] <= 2.5\ngini = 0.426\nsamples = 26\nvalue = [18, 8]'),
#  Text(0.02774332133240553, 0.6379310344827587, 'X[5] <= 874.0\ngini = 0.488\nsamples = 19\nvalue = [11, 8]'),
#  Text(0.025807037182706563, 0.603448275862069, 'X[5] <= 31.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.024838895107857077, 0.5689655172413793, 'X[13] <= 86.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.023870753033007595, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.025807037182706563, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.026775179257556046, 0.5689655172413793, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.0296796054821045, 0.603448275862069, 'X[10] <= 2.0\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.028711463407255014, 0.5689655172413793, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.030647747556953982, 0.5689655172413793, 'X[5] <= 3830.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.0296796054821045, 0.5344827586206896, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.031615889631803465, 0.5344827586206896, 'X[3] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.030647747556953982, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03258403170665295, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0296796054821045, 0.6379310344827587, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.03669863552476326, 0.6724137931034483, 'X[13] <= 179.5\ngini = 0.174\nsamples = 104\nvalue = [94, 10]'),
#  Text(0.035730493449913775, 0.6379310344827587, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.03766677759961274, 0.6379310344827587, 'X[13] <= 181.0\ngini = 0.236\nsamples = 73\nvalue = [63, 10]'),
#  Text(0.03669863552476326, 0.603448275862069, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.038634919674462226, 0.603448275862069, 'X[0] <= 31.5\ngini = 0.219\nsamples = 72\nvalue = [63, 9]'),
#  Text(0.03452031585635192, 0.5689655172413793, 'X[0] <= 29.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.03355217378150244, 0.5344827586206896, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.0354884579312014, 0.5344827586206896, 'X[13] <= 246.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03452031585635192, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03645660000605089, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.042749523492572536, 0.5689655172413793, 'X[2] <= 0.5\ngini = 0.158\nsamples = 58\nvalue = [53, 5]'),
#  Text(0.03936102623059934, 0.5344827586206896, 'X[5] <= 376.0\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.03839288415574986, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.040329168305448825, 0.5, 'X[10] <= 7.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.03936102623059934, 0.46551724137931033, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.04129731038029831, 0.46551724137931033, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.046138020754545726, 0.5344827586206896, 'X[13] <= 183.5\ngini = 0.08\nsamples = 48\nvalue = [46, 2]'),
#  Text(0.04420173660484676, 0.5, 'X[0] <= 50.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.043233594529997275, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04516987867969625, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0480743049042447, 0.5, 'X[1] <= 8.0\ngini = 0.043\nsamples = 46\nvalue = [45, 1]'),
#  Text(0.04710616282939521, 0.46551724137931033, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.049042446979094184, 0.46551724137931033, 'X[13] <= 233.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.0480743049042447, 0.43103448275862066, 'X[14] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04710616282939521, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.049042446979094184, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05001058905394366, 0.43103448275862066, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.034641333615708106, 0.7068965517241379, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04347563004870965, 0.7413793103448276, 'X[13] <= 111.5\ngini = 0.444\nsamples = 30\nvalue = [10, 20]'),
#  Text(0.04153934589901068, 0.7068965517241379, 'X[9] <= 2.5\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(0.0405712038241612, 0.6724137931034483, 'X[13] <= 73.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.03960306174931171, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04153934589901068, 0.6379310344827587, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.04250748797386016, 0.6724137931034483, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.045411914198408614, 0.7068965517241379, 'X[13] <= 183.0\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.044443772123559135, 0.6724137931034483, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.0463800562732581, 0.6724137931034483, 'X[2] <= 1.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.045411914198408614, 0.6379310344827587, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.047348198348107585, 0.6379310344827587, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06493453695579826, 0.7758620689655172, 'X[10] <= 0.5\ngini = 0.163\nsamples = 680\nvalue = [619, 61]'),
#  Text(0.05581944150304057, 0.7413793103448276, 'X[1] <= 8.0\ngini = 0.465\nsamples = 38\nvalue = [24, 14]'),
#  Text(0.054851299428191086, 0.7068965517241379, 'X[6] <= 0.5\ngini = 0.397\nsamples = 33\nvalue = [24, 9]'),
#  Text(0.05291501527849212, 0.6724137931034483, 'X[9] <= 25.0\ngini = 0.484\nsamples = 17\nvalue = [10, 7]'),
#  Text(0.051946873203642635, 0.6379310344827587, 'X[11] <= 126.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.05097873112879315, 0.603448275862069, 'X[0] <= 31.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.05001058905394366, 0.5689655172413793, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.051946873203642635, 0.5689655172413793, 'X[9] <= 7.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.05097873112879315, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05291501527849212, 0.5344827586206896, 'X[5] <= 88.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.051946873203642635, 0.5, 'X[0] <= 40.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05097873112879315, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05291501527849212, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0538831573533416, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.05291501527849212, 0.603448275862069, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0538831573533416, 0.6379310344827587, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.05678758357789006, 0.6724137931034483, 'X[12] <= 5.5\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.05581944150304057, 0.6379310344827587, 'X[0] <= 34.0\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.054851299428191086, 0.603448275862069, 'X[0] <= 31.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0538831573533416, 0.5689655172413793, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05581944150304057, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05678758357789006, 0.603448275862069, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.05775572565273954, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05678758357789006, 0.7068965517241379, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.07404963240855596, 0.7413793103448276, 'X[0] <= 67.0\ngini = 0.136\nsamples = 642\nvalue = [595, 47]'),
#  Text(0.06679045774967476, 0.7068965517241379, 'X[9] <= 3.5\ngini = 0.124\nsamples = 633\nvalue = [591, 42]'),
#  Text(0.061628293952137474, 0.6724137931034483, 'X[8] <= 1.0\ngini = 0.375\nsamples = 36\nvalue = [27, 9]'),
#  Text(0.060660151877287995, 0.6379310344827587, 'X[1] <= 7.5\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.05969200980243851, 0.603448275862069, 'X[1] <= 0.5\ngini = 0.43\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.05775572565273954, 0.5689655172413793, 'X[0] <= 29.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.05678758357789006, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05872386772758902, 0.5344827586206896, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.061628293952137474, 0.5689655172413793, 'X[10] <= 6.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.060660151877287995, 0.5344827586206896, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.06259643602698696, 0.5344827586206896, 'X[2] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.061628293952137474, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06356457810183644, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.061628293952137474, 0.603448275862069, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06259643602698696, 0.6379310344827587, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.07195262154721205, 0.6724137931034483, 'X[5] <= 148.0\ngini = 0.104\nsamples = 597\nvalue = [564, 33]'),
#  Text(0.06453272017668593, 0.6379310344827587, 'X[11] <= 123.5\ngini = 0.01\nsamples = 198\nvalue = [197, 1]'),
#  Text(0.06356457810183644, 0.603448275862069, 'gini = 0.0\nsamples = 183\nvalue = [183, 0]'),
#  Text(0.06550086225153541, 0.603448275862069, 'X[0] <= 50.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.06453272017668593, 0.5689655172413793, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.0664690043263849, 0.5689655172413793, 'X[9] <= 15.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06550086225153541, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06743714640123438, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07937252291773818, 0.6379310344827587, 'X[5] <= 199.5\ngini = 0.148\nsamples = 399\nvalue = [367, 32]'),
#  Text(0.0722778567754818, 0.603448275862069, 'X[5] <= 195.0\ngini = 0.397\nsamples = 22\nvalue = [16, 6]'),
#  Text(0.07034157262578283, 0.5689655172413793, 'X[5] <= 152.0\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.06937343055093335, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07130971470063231, 0.5344827586206896, 'X[0] <= 28.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.07034157262578283, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0722778567754818, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.07421414092518078, 0.5689655172413793, 'X[12] <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.07324599885033128, 0.5344827586206896, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.07518228300003026, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08646718905999455, 0.603448275862069, 'X[1] <= 0.5\ngini = 0.128\nsamples = 377\nvalue = [351, 26]'),
#  Text(0.07905485129942819, 0.5689655172413793, 'X[2] <= 0.5\ngini = 0.313\nsamples = 36\nvalue = [29, 7]'),
#  Text(0.07711856714972923, 0.5344827586206896, 'X[7] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.07615042507487974, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.07808670922457871, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08099113544912716, 0.5344827586206896, 'X[9] <= 17.5\ngini = 0.225\nsamples = 31\nvalue = [27, 4]'),
#  Text(0.08002299337427768, 0.5, 'X[9] <= 16.5\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.07808670922457871, 0.46551724137931033, 'X[5] <= 3500.0\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.07711856714972923, 0.43103448275862066, 'X[0] <= 54.0\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.07615042507487974, 0.39655172413793105, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.07808670922457871, 0.39655172413793105, 'X[10] <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07711856714972923, 0.3620689655172414, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07905485129942819, 0.3620689655172414, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07905485129942819, 0.43103448275862066, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08195927752397664, 0.46551724137931033, 'X[6] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08099113544912716, 0.43103448275862066, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08292741959882613, 0.43103448275862066, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08195927752397664, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.09387952682056092, 0.5689655172413793, 'X[1] <= 8.5\ngini = 0.105\nsamples = 341\nvalue = [322, 19]'),
#  Text(0.08837321876985448, 0.5344827586206896, 'X[11] <= 80.5\ngini = 0.059\nsamples = 262\nvalue = [254, 8]'),
#  Text(0.08534777478594983, 0.5, 'X[9] <= 10.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.08437963271110036, 0.46551724137931033, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08631591686079933, 0.46551724137931033, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.09139866275375912, 0.5, 'X[12] <= 1.5\ngini = 0.046\nsamples = 257\nvalue = [251, 6]'),
#  Text(0.08825220101049829, 0.46551724137931033, 'X[0] <= 33.5\ngini = 0.123\nsamples = 76\nvalue = [71, 5]'),
#  Text(0.0848637037485251, 0.43103448275862066, 'X[0] <= 31.5\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.08389556167367561, 0.39655172413793105, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.08583184582337458, 0.39655172413793105, 'X[11] <= 102.0\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.08389556167367561, 0.3620689655172414, 'X[2] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.08292741959882613, 0.3275862068965517, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0848637037485251, 0.3275862068965517, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08776812997307355, 0.3620689655172414, 'X[6] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.08679998789822406, 0.3275862068965517, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08873627204792303, 0.3275862068965517, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.09164069827247148, 0.43103448275862066, 'X[10] <= 2.5\ngini = 0.034\nsamples = 57\nvalue = [56, 1]'),
#  Text(0.090672556197622, 0.39655172413793105, 'X[8] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.08970441412277251, 0.3620689655172414, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.09164069827247148, 0.3620689655172414, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09260884034732098, 0.39655172413793105, 'gini = 0.0\nsamples = 49\nvalue = [49, 0]'),
#  Text(0.09454512449701993, 0.46551724137931033, 'X[0] <= 58.5\ngini = 0.011\nsamples = 181\nvalue = [180, 1]'),
#  Text(0.09357698242217045, 0.43103448275862066, 'gini = 0.0\nsamples = 169\nvalue = [169, 0]'),
#  Text(0.09551326657186943, 0.43103448275862066, 'X[2] <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.09454512449701993, 0.39655172413793105, 'X[1] <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09357698242217045, 0.3620689655172414, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09551326657186943, 0.3620689655172414, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0964814086467189, 0.39655172413793105, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.09938583487126736, 0.5344827586206896, 'X[0] <= 29.5\ngini = 0.24\nsamples = 79\nvalue = [68, 11]'),
#  Text(0.09744955072156838, 0.5, 'X[11] <= 106.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0964814086467189, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09841769279641788, 0.46551724137931033, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.10132211902096633, 0.5, 'X[10] <= 7.5\ngini = 0.209\nsamples = 76\nvalue = [67, 9]'),
#  Text(0.10035397694611685, 0.46551724137931033, 'X[10] <= 6.5\ngini = 0.295\nsamples = 50\nvalue = [41, 9]'),
#  Text(0.09938583487126736, 0.43103448275862066, 'X[10] <= 2.0\ngini = 0.249\nsamples = 48\nvalue = [41, 7]'),
#  Text(0.09841769279641788, 0.39655172413793105, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.10035397694611685, 0.39655172413793105, 'X[10] <= 3.5\ngini = 0.366\nsamples = 29\nvalue = [22, 7]'),
#  Text(0.09841769279641788, 0.3620689655172414, 'X[9] <= 8.0\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.09744955072156838, 0.3275862068965517, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.09938583487126736, 0.3275862068965517, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.10229026109581581, 0.3620689655172414, 'X[11] <= 115.5\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.10132211902096633, 0.3275862068965517, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.1032584031706653, 0.3275862068965517, 'X[0] <= 44.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.10229026109581581, 0.29310344827586204, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.10422654524551478, 0.29310344827586204, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10132211902096633, 0.43103448275862066, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.10229026109581581, 0.46551724137931033, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.08130880706743715, 0.7068965517241379, 'X[0] <= 73.0\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.08034066499258766, 0.6724137931034483, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08227694914228663, 0.6724137931034483, 'X[11] <= 111.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.08130880706743715, 0.6379310344827587, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.08324509121713611, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0850603576074789, 0.8793103448275862, 'X[11] <= 77.5\ngini = 0.499\nsamples = 59\nvalue = [31, 28]'),
#  Text(0.08130880706743715, 0.8448275862068966, 'X[9] <= 25.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.08034066499258766, 0.8103448275862069, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.08227694914228663, 0.8103448275862069, 'X[1] <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08130880706743715, 0.7758620689655172, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08324509121713611, 0.7758620689655172, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08881190814752064, 0.8448275862068966, 'X[9] <= 9.5\ngini = 0.467\nsamples = 43\nvalue = [16, 27]'),
#  Text(0.08614951744168457, 0.8103448275862069, 'X[11] <= 110.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.08518137536683508, 0.7758620689655172, 'X[13] <= 100.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.0842132332919856, 0.7413793103448276, 'X[5] <= 1868.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.08324509121713611, 0.7068965517241379, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08518137536683508, 0.7068965517241379, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08614951744168457, 0.7413793103448276, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.08711765951653405, 0.7758620689655172, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.09147429885335673, 0.8103448275862069, 'X[0] <= 74.5\ngini = 0.375\nsamples = 32\nvalue = [8, 24]'),
#  Text(0.09050615677850725, 0.7758620689655172, 'X[0] <= 29.0\ngini = 0.32\nsamples = 30\nvalue = [6, 24]'),
#  Text(0.08808580159138353, 0.7413793103448276, 'X[5] <= 969.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.08711765951653405, 0.7068965517241379, 'X[14] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.08614951744168457, 0.6724137931034483, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08808580159138353, 0.6724137931034483, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08905394366623302, 0.7068965517241379, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09292651196563095, 0.7413793103448276, 'X[12] <= 4.0\ngini = 0.219\nsamples = 24\nvalue = [3, 21]'),
#  Text(0.09195836989078147, 0.7068965517241379, 'X[5] <= 237.5\ngini = 0.159\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.0900220857410825, 0.6724137931034483, 'X[14] <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08905394366623302, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09099022781593198, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09389465404048045, 0.6724137931034483, 'X[13] <= 182.5\ngini = 0.091\nsamples = 21\nvalue = [1, 20]'),
#  Text(0.09292651196563095, 0.6379310344827587, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.09486279611532993, 0.6379310344827587, 'X[14] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.09389465404048045, 0.603448275862069, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0958309381901794, 0.603448275862069, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09389465404048045, 0.7068965517241379, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09244244092820622, 0.7758620689655172, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22391547287689467, 0.9137931034482759, 'X[13] <= 45.0\ngini = 0.452\nsamples = 1408\nvalue = [921, 487]'),
#  Text(0.19202209330469247, 0.8793103448275862, 'X[8] <= 1.5\ngini = 0.369\nsamples = 1051\nvalue = [794, 257]'),
#  Text(0.17065962242459082, 0.8448275862068966, 'X[0] <= 60.5\ngini = 0.443\nsamples = 748\nvalue = [500, 248]'),
#  Text(0.13664795933803286, 0.8103448275862069, 'X[0] <= 28.5\ngini = 0.417\nsamples = 696\nvalue = [490, 206]'),
#  Text(0.11415000151272199, 0.7758620689655172, 'X[6] <= 0.5\ngini = 0.484\nsamples = 102\nvalue = [42, 60]'),
#  Text(0.11051946873203643, 0.7413793103448276, 'X[9] <= 27.5\ngini = 0.433\nsamples = 79\nvalue = [25, 54]'),
#  Text(0.10858318458233746, 0.7068965517241379, 'X[10] <= 0.5\ngini = 0.36\nsamples = 68\nvalue = [16, 52]'),
#  Text(0.10761504250748798, 0.6724137931034483, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.10955132665718695, 0.6724137931034483, 'X[5] <= 1.5\ngini = 0.431\nsamples = 51\nvalue = [16, 35]'),
#  Text(0.10858318458233746, 0.6379310344827587, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.11051946873203643, 0.6379310344827587, 'X[10] <= 6.5\ngini = 0.395\nsamples = 48\nvalue = [13, 35]'),
#  Text(0.10713097147006323, 0.603448275862069, 'X[9] <= 18.5\ngini = 0.469\nsamples = 32\nvalue = [12, 20]'),
#  Text(0.10519468732036426, 0.5689655172413793, 'X[1] <= 8.5\ngini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(0.10422654524551478, 0.5344827586206896, 'X[11] <= 133.5\ngini = 0.245\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.1032584031706653, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10519468732036426, 0.5, 'X[5] <= 226.0\ngini = 0.18\nsamples = 20\nvalue = [2, 18]'),
#  Text(0.10422654524551478, 0.46551724137931033, 'X[9] <= 9.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.1032584031706653, 0.43103448275862066, 'X[0] <= 24.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.10229026109581581, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10422654524551478, 0.39655172413793105, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10519468732036426, 0.43103448275862066, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.10616282939521375, 0.46551724137931033, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.10616282939521375, 0.5344827586206896, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1090672556197622, 0.5689655172413793, 'X[11] <= 134.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.10809911354491272, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11003539769461168, 0.5344827586206896, 'X[12] <= 4.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.1090672556197622, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.11100353976946117, 0.5, 'X[0] <= 25.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11003539769461168, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11197168184431065, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11390796599400962, 0.603448275862069, 'X[11] <= 137.5\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.11293982391916013, 0.5689655172413793, 'X[0] <= 24.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.11197168184431065, 0.5344827586206896, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.11390796599400962, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1148761080688591, 0.5689655172413793, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.1124557528817354, 0.7068965517241379, 'X[5] <= 1664.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.1114876108068859, 0.6724137931034483, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.11342389495658488, 0.6724137931034483, 'X[0] <= 27.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1124557528817354, 0.6379310344827587, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11439203703143436, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11778053429340755, 0.7413793103448276, 'X[10] <= 9.5\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.11681239221855808, 0.7068965517241379, 'X[12] <= 2.5\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.11584425014370858, 0.6724137931034483, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.11778053429340755, 0.6724137931034483, 'X[3] <= 1.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.11681239221855808, 0.6379310344827587, 'X[14] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.11584425014370858, 0.603448275862069, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.11778053429340755, 0.603448275862069, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11874867636825705, 0.6379310344827587, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11874867636825705, 0.7068965517241379, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.15914591716334373, 0.7758620689655172, 'X[5] <= 911.0\ngini = 0.371\nsamples = 594\nvalue = [448, 146]'),
#  Text(0.13676519529240916, 0.7413793103448276, 'X[10] <= 9.5\ngini = 0.28\nsamples = 381\nvalue = [317, 64]'),
#  Text(0.13075968898435844, 0.7068965517241379, 'X[10] <= 0.5\ngini = 0.254\nsamples = 369\nvalue = [314, 55]'),
#  Text(0.1216531025928055, 0.6724137931034483, 'X[11] <= 189.5\ngini = 0.491\nsamples = 30\nvalue = [17, 13]'),
#  Text(0.120684960517956, 0.6379310344827587, 'X[1] <= 8.0\ngini = 0.491\nsamples = 23\nvalue = [10, 13]'),
#  Text(0.11971681844310653, 0.603448275862069, 'X[6] <= 0.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.11778053429340755, 0.5689655172413793, 'X[5] <= 223.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.11681239221855808, 0.5344827586206896, 'X[0] <= 32.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.11584425014370858, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.11778053429340755, 0.5, 'X[9] <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11681239221855808, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11874867636825705, 0.46551724137931033, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11874867636825705, 0.5344827586206896, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.1216531025928055, 0.5689655172413793, 'X[9] <= 25.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.120684960517956, 0.5344827586206896, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12262124466765498, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1216531025928055, 0.603448275862069, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.12262124466765498, 0.6379310344827587, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.13986627537591143, 0.6724137931034483, 'X[10] <= 5.5\ngini = 0.217\nsamples = 339\nvalue = [297, 42]'),
#  Text(0.1318185943787251, 0.6379310344827587, 'X[6] <= 0.5\ngini = 0.128\nsamples = 233\nvalue = [217, 16]'),
#  Text(0.1308504523038756, 0.603448275862069, 'X[10] <= 1.5\ngini = 0.174\nsamples = 166\nvalue = [150, 16]'),
#  Text(0.12649381296705292, 0.5689655172413793, 'X[0] <= 59.5\ngini = 0.05\nsamples = 78\nvalue = [76, 2]'),
#  Text(0.12455752881735395, 0.5344827586206896, 'X[5] <= 744.0\ngini = 0.026\nsamples = 75\nvalue = [74, 1]'),
#  Text(0.12358938674250446, 0.5, 'gini = 0.0\nsamples = 71\nvalue = [71, 0]'),
#  Text(0.12552567089220343, 0.5, 'X[5] <= 801.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.12455752881735395, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12649381296705292, 0.46551724137931033, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12843009711675188, 0.5344827586206896, 'X[5] <= 261.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12746195504190239, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12939823919160137, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13520709164069827, 0.5689655172413793, 'X[10] <= 3.5\ngini = 0.268\nsamples = 88\nvalue = [74, 14]'),
#  Text(0.13230266541614982, 0.5344827586206896, 'X[9] <= 9.0\ngini = 0.461\nsamples = 25\nvalue = [16, 9]'),
#  Text(0.13133452334130033, 0.5, 'X[3] <= 1.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.12843009711675188, 0.46551724137931033, 'X[7] <= 0.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.12746195504190239, 0.43103448275862066, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.12939823919160137, 0.43103448275862066, 'X[1] <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12843009711675188, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13036638126645086, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13423894956584878, 0.46551724137931033, 'X[0] <= 45.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.13327080749099932, 0.43103448275862066, 'X[5] <= 202.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.13230266541614982, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13423894956584878, 0.39655172413793105, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13520709164069827, 0.43103448275862066, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13327080749099932, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.13811151786524672, 0.5344827586206896, 'X[0] <= 35.5\ngini = 0.146\nsamples = 63\nvalue = [58, 5]'),
#  Text(0.13714337579039723, 0.5, 'X[5] <= 1.0\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.13617523371554777, 0.46551724137931033, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13811151786524672, 0.46551724137931033, 'X[5] <= 752.5\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.13714337579039723, 0.43103448275862066, 'X[3] <= 0.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.13617523371554777, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13811151786524672, 0.39655172413793105, 'X[1] <= 0.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.13714337579039723, 0.3620689655172414, 'X[12] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.13617523371554777, 0.3275862068965517, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13811151786524672, 0.3275862068965517, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13907965994009622, 0.3620689655172414, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.13907965994009622, 0.43103448275862066, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13907965994009622, 0.5, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(0.13278673645357456, 0.603448275862069, 'gini = 0.0\nsamples = 67\nvalue = [67, 0]'),
#  Text(0.14791395637309776, 0.6379310344827587, 'X[10] <= 7.5\ngini = 0.37\nsamples = 106\nvalue = [80, 26]'),
#  Text(0.14295222823949413, 0.603448275862069, 'X[11] <= 151.0\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.14101594408979518, 0.5689655172413793, 'X[10] <= 6.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.14004780201494568, 0.5344827586206896, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14198408616464467, 0.5344827586206896, 'X[5] <= 146.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.14101594408979518, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.14295222823949413, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14488851238919312, 0.5689655172413793, 'X[12] <= 3.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.14392037031434363, 0.5344827586206896, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.14585665446404258, 0.5344827586206896, 'X[3] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14488851238919312, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14682479653889208, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15287568450670136, 0.603448275862069, 'X[9] <= 4.0\ngini = 0.156\nsamples = 82\nvalue = [75, 7]'),
#  Text(0.15190754243185187, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15384382658155085, 0.5689655172413793, 'X[8] <= 0.5\ngini = 0.137\nsamples = 81\nvalue = [75, 6]'),
#  Text(0.15118143587571475, 0.5344827586206896, 'X[9] <= 21.5\ngini = 0.098\nsamples = 77\nvalue = [73, 4]'),
#  Text(0.14876108068859106, 0.5, 'X[2] <= 1.5\ngini = 0.056\nsamples = 70\nvalue = [68, 2]'),
#  Text(0.14779293861374157, 0.46551724137931033, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]'),
#  Text(0.14972922276344053, 0.46551724137931033, 'X[11] <= 189.5\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.14779293861374157, 0.43103448275862066, 'X[5] <= 5.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.14682479653889208, 0.39655172413793105, 'X[1] <= 5.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.14585665446404258, 0.3620689655172414, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14779293861374157, 0.3620689655172414, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14876108068859106, 0.39655172413793105, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.15166550691313951, 0.43103448275862066, 'X[9] <= 9.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.15069736483829002, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15263364898798898, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15360179106283847, 0.5, 'X[11] <= 174.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.15263364898798898, 0.46551724137931033, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.15456993313768796, 0.46551724137931033, 'X[5] <= 455.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.15360179106283847, 0.43103448275862066, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15553807521253743, 0.43103448275862066, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15650621728738692, 0.5344827586206896, 'X[3] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.15553807521253743, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15747435936223642, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14277070160045988, 0.7068965517241379, 'X[9] <= 22.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.14180255952561038, 0.6724137931034483, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14373884367530934, 0.6724137931034483, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.1815266390342783, 0.7413793103448276, 'X[6] <= 0.5\ngini = 0.474\nsamples = 213\nvalue = [131, 82]'),
#  Text(0.16903155538075212, 0.7068965517241379, 'X[12] <= 3.5\ngini = 0.499\nsamples = 133\nvalue = [69, 64]'),
#  Text(0.1609838743835658, 0.6724137931034483, 'X[10] <= 0.5\ngini = 0.494\nsamples = 110\nvalue = [49, 61]'),
#  Text(0.1557801107312498, 0.6379310344827587, 'X[0] <= 55.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.15481196865640032, 0.603448275862069, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.1567482528060993, 0.603448275862069, 'X[5] <= 1787.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1557801107312498, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15771639488094877, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16618763803588177, 0.6379310344827587, 'X[9] <= 3.5\ngini = 0.5\nsamples = 97\nvalue = [48, 49]'),
#  Text(0.1615889631803467, 0.603448275862069, 'X[1] <= 0.5\ngini = 0.305\nsamples = 16\nvalue = [3, 13]'),
#  Text(0.15965267903064775, 0.5689655172413793, 'X[9] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.15868453695579826, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16062082110549722, 0.5344827586206896, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1635252473300457, 0.5689655172413793, 'X[1] <= 9.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.1625571052551962, 0.5344827586206896, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.16449338940489516, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17078631289141682, 0.603448275862069, 'X[3] <= 0.5\ngini = 0.494\nsamples = 81\nvalue = [45, 36]'),
#  Text(0.1673978156294436, 0.5689655172413793, 'X[0] <= 56.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.16642967355459415, 0.5344827586206896, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.1683659577042931, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17417481015339, 0.5689655172413793, 'X[9] <= 16.5\ngini = 0.5\nsamples = 70\nvalue = [35, 35]'),
#  Text(0.17030224185399206, 0.5344827586206896, 'X[5] <= 2224.5\ngini = 0.463\nsamples = 33\nvalue = [12, 21]'),
#  Text(0.16788188666686837, 0.5, 'X[10] <= 4.5\ngini = 0.488\nsamples = 19\nvalue = [11, 8]'),
#  Text(0.1659456025171694, 0.46551724137931033, 'X[0] <= 48.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.16497746044231992, 0.43103448275862066, 'X[0] <= 30.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.16400931836747043, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1659456025171694, 0.39655172413793105, 'X[9] <= 13.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.16497746044231992, 0.3620689655172414, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.16691374459201888, 0.3620689655172414, 'X[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1659456025171694, 0.3275862068965517, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16788188666686837, 0.3275862068965517, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16691374459201888, 0.43103448275862066, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.16981817081656733, 0.46551724137931033, 'X[10] <= 10.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.16885002874171784, 0.43103448275862066, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.17078631289141682, 0.43103448275862066, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17272259704111578, 0.5, 'X[5] <= 16241.0\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.1717544549662663, 0.46551724137931033, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.17369073911596528, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17804737845278795, 0.5344827586206896, 'X[8] <= 0.5\ngini = 0.47\nsamples = 37\nvalue = [23, 14]'),
#  Text(0.17707923637793846, 0.5, 'X[10] <= 8.5\ngini = 0.422\nsamples = 33\nvalue = [23, 10]'),
#  Text(0.17611109430308897, 0.46551724137931033, 'X[0] <= 51.5\ngini = 0.499\nsamples = 21\nvalue = [11, 10]'),
# ...
#  Text(0.34045321150878893, 0.5344827586206896, 'X[5] <= 6030.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.3394850694339394, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3414213535836384, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34238949565848786, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3452939218830363, 0.5689655172413793, 'X[11] <= 350.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.34432577980818685, 0.5344827586206896, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.34626206395788584, 0.5344827586206896, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3452939218830363, 0.603448275862069, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35521737815024357, 0.7068965517241379, 'X[9] <= 4.5\ngini = 0.481\nsamples = 62\nvalue = [25, 37]'),
#  Text(0.35424923607539405, 0.6724137931034483, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.35618552022509303, 0.6724137931034483, 'X[9] <= 21.5\ngini = 0.498\nsamples = 53\nvalue = [25, 28]'),
#  Text(0.35352312951925696, 0.6379310344827587, 'X[5] <= 1526.5\ngini = 0.488\nsamples = 38\nvalue = [22, 16]'),
#  Text(0.3511027743321332, 0.603448275862069, 'X[14] <= 11.0\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.35013463225728375, 0.5689655172413793, 'X[1] <= 7.5\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.34819834810758477, 0.5344827586206896, 'X[13] <= 359.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.3472302060327353, 0.5, 'X[12] <= 4.5\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.34626206395788584, 0.46551724137931033, 'X[0] <= 59.0\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.3452939218830363, 0.43103448275862066, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.3472302060327353, 0.43103448275862066, 'X[5] <= 680.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.34626206395788584, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34819834810758477, 0.39655172413793105, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34819834810758477, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3491664901824343, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35207091640698274, 0.5344827586206896, 'X[11] <= 428.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3511027743321332, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3530390584818322, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35207091640698274, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35594348470638065, 0.603448275862069, 'X[12] <= 1.5\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.3549753426315312, 0.5689655172413793, 'X[10] <= 7.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.35400720055668167, 0.5344827586206896, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35594348470638065, 0.5344827586206896, 'X[11] <= 277.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.3549753426315312, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3569116267812301, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3569116267812301, 0.5689655172413793, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.3588479109309291, 0.6379310344827587, 'X[9] <= 27.5\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.35787976885607964, 0.603448275862069, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.3598160530057786, 0.603448275862069, 'X[11] <= 291.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3588479109309291, 0.5689655172413793, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3607841950806281, 0.5689655172413793, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.36005808852449095, 0.7413793103448276, 'X[5] <= 253.5\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.3590899464496415, 0.7068965517241379, 'X[11] <= 256.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.358121804374792, 0.6724137931034483, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36005808852449095, 0.6724137931034483, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36102623059934047, 0.7068965517241379, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.37725773757298886, 0.8103448275862069, 'X[14] <= 10.5\ngini = 0.109\nsamples = 380\nvalue = [22, 358]'),
#  Text(0.37333978761383235, 0.7758620689655172, 'X[11] <= 207.5\ngini = 0.1\nsamples = 377\nvalue = [20, 357]'),
#  Text(0.3684083139200678, 0.7413793103448276, 'X[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.36744017184521827, 0.7068965517241379, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36937645599491725, 0.7068965517241379, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37827126130759686, 0.7413793103448276, 'X[6] <= 0.5\ngini = 0.096\nsamples = 375\nvalue = [19, 356]'),
#  Text(0.37131274014461624, 0.7068965517241379, 'X[13] <= 175.5\ngini = 0.062\nsamples = 279\nvalue = [9, 270]'),
#  Text(0.3687713671981363, 0.6724137931034483, 'X[13] <= 174.0\ngini = 0.116\nsamples = 129\nvalue = [8, 121]'),
#  Text(0.36780322512328684, 0.6379310344827587, 'X[2] <= 0.5\ngini = 0.103\nsamples = 128\nvalue = [7, 121]'),
#  Text(0.36368862130517654, 0.603448275862069, 'X[13] <= 98.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.3627204792303271, 0.5689655172413793, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.364656763380026, 0.5689655172413793, 'X[9] <= 18.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.36368862130517654, 0.5344827586206896, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3656249054548755, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.37191782894139713, 0.603448275862069, 'X[7] <= 0.5\ngini = 0.079\nsamples = 121\nvalue = [5, 116]'),
#  Text(0.36949747375427344, 0.5689655172413793, 'X[5] <= 389.5\ngini = 0.065\nsamples = 118\nvalue = [4, 114]'),
#  Text(0.36756118960457446, 0.5344827586206896, 'X[5] <= 377.0\ngini = 0.142\nsamples = 39\nvalue = [3, 36]'),
#  Text(0.366593047529725, 0.5, 'X[13] <= 73.0\ngini = 0.1\nsamples = 38\nvalue = [2, 36]'),
#  Text(0.364656763380026, 0.46551724137931033, 'X[1] <= 7.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.36368862130517654, 0.43103448275862066, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3656249054548755, 0.43103448275862066, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.368529331679424, 0.46551724137931033, 'X[9] <= 6.5\ngini = 0.057\nsamples = 34\nvalue = [1, 33]'),
#  Text(0.36756118960457446, 0.43103448275862066, 'X[14] <= 2.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.366593047529725, 0.39655172413793105, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.368529331679424, 0.39655172413793105, 'X[3] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.36756118960457446, 0.3620689655172414, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36949747375427344, 0.3620689655172414, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36949747375427344, 0.43103448275862066, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.368529331679424, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37143375790397243, 0.5344827586206896, 'X[13] <= 104.5\ngini = 0.025\nsamples = 79\nvalue = [1, 78]'),
#  Text(0.3704656158291229, 0.5, 'gini = 0.0\nsamples = 66\nvalue = [0, 66]'),
#  Text(0.3724018999788219, 0.5, 'X[1] <= 8.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.37143375790397243, 0.46551724137931033, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.37337004205367136, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3743381841285209, 0.5689655172413793, 'X[5] <= 3359.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.37337004205367136, 0.5344827586206896, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.37530632620337034, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3697395092729858, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3738541130910961, 0.6724137931034483, 'X[0] <= 76.5\ngini = 0.013\nsamples = 150\nvalue = [1, 149]'),
#  Text(0.37288597101624665, 0.6379310344827587, 'gini = 0.0\nsamples = 143\nvalue = [0, 143]'),
#  Text(0.3748222551659456, 0.6379310344827587, 'X[10] <= 2.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.3738541130910961, 0.603448275862069, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3757903972407951, 0.603448275862069, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.38522978247057754, 0.7068965517241379, 'X[12] <= 4.5\ngini = 0.187\nsamples = 96\nvalue = [10, 86]'),
#  Text(0.3820833207273167, 0.6724137931034483, 'X[11] <= 225.5\ngini = 0.142\nsamples = 91\nvalue = [7, 84]'),
#  Text(0.37869482346534356, 0.6379310344827587, 'X[5] <= 1793.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.37772668139049403, 0.603448275862069, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.379662965540193, 0.603448275862069, 'X[10] <= 7.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.37869482346534356, 0.5689655172413793, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3806311076150425, 0.5689655172413793, 'X[2] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.379662965540193, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.381599249689892, 0.5344827586206896, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3854718179892899, 0.6379310344827587, 'X[11] <= 420.0\ngini = 0.096\nsamples = 79\nvalue = [4, 75]'),
#  Text(0.38353553383959094, 0.603448275862069, 'X[12] <= 1.5\ngini = 0.076\nsamples = 76\nvalue = [3, 73]'),
#  Text(0.38256739176474147, 0.5689655172413793, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(0.38450367591444046, 0.5689655172413793, 'X[0] <= 35.5\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.38353553383959094, 0.5344827586206896, 'X[13] <= 156.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.38256739176474147, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.38450367591444046, 0.5, 'X[1] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.38353553383959094, 0.46551724137931033, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3854718179892899, 0.46551724137931033, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3854718179892899, 0.5344827586206896, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.3874081021389889, 0.603448275862069, 'X[13] <= 223.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3864399600641394, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3883762442138384, 0.5689655172413793, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3883762442138384, 0.6724137931034483, 'X[8] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.3874081021389889, 0.6379310344827587, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.38934438628868784, 0.6379310344827587, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.38117568753214537, 0.7758620689655172, 'X[14] <= 13.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.38020754545729585, 0.7413793103448276, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.38214382960699483, 0.7413793103448276, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5269497331936587, 0.8448275862068966, 'X[6] <= 0.5\ngini = 0.5\nsamples = 1221\nvalue = [610, 611]'),
#  Text(0.4678407122651499, 0.8103448275862069, 'X[10] <= 5.5\ngini = 0.481\nsamples = 805\nvalue = [325, 480]'),
#  Text(0.4235342669349227, 0.7758620689655172, 'X[10] <= 0.5\ngini = 0.5\nsamples = 528\nvalue = [264, 264]'),
#  Text(0.39648443409070283, 0.7413793103448276, 'X[5] <= 514.0\ngini = 0.278\nsamples = 96\nvalue = [16, 80]'),
#  Text(0.3912806704383868, 0.7068965517241379, 'X[8] <= 0.5\ngini = 0.056\nsamples = 35\nvalue = [1, 34]'),
#  Text(0.39031252836353736, 0.6724137931034483, 'gini = 0.0\nsamples = 33\nvalue = [0, 33]'),
#  Text(0.39224881251323634, 0.6724137931034483, 'X[5] <= 237.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3912806704383868, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3932169545880858, 0.6379310344827587, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4016881977430188, 0.7068965517241379, 'X[0] <= 32.5\ngini = 0.371\nsamples = 61\nvalue = [15, 46]'),
#  Text(0.39612138081263426, 0.6724137931034483, 'X[5] <= 1225.5\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(0.3951532387377848, 0.6379310344827587, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3970895228874837, 0.6379310344827587, 'X[5] <= 3793.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.3951532387377848, 0.603448275862069, 'X[8] <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.3941850966629353, 0.5689655172413793, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.39612138081263426, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3990258070371827, 0.603448275862069, 'X[11] <= 332.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.39805766496233325, 0.5689655172413793, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3999939491120322, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4072550146734033, 0.6724137931034483, 'X[11] <= 404.0\ngini = 0.245\nsamples = 42\nvalue = [6, 36]'),
#  Text(0.4048346594862796, 0.6379310344827587, 'X[0] <= 35.5\ngini = 0.153\nsamples = 36\nvalue = [3, 33]'),
#  Text(0.4028983753365806, 0.603448275862069, 'X[11] <= 305.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.40193023326173116, 0.5689655172413793, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.40386651741143015, 0.5689655172413793, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4067709436359786, 0.603448275862069, 'X[9] <= 5.0\ngini = 0.062\nsamples = 31\nvalue = [1, 30]'),
#  Text(0.4058028015611291, 0.5689655172413793, 'X[5] <= 4364.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4048346594862796, 0.5344827586206896, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4067709436359786, 0.5344827586206896, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.40773908571082806, 0.5689655172413793, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.40967536986052705, 0.6379310344827587, 'X[9] <= 29.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.40870722778567753, 0.603448275862069, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4106435119353765, 0.603448275862069, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4505840997791426, 0.7413793103448276, 'X[5] <= 113.0\ngini = 0.489\nsamples = 432\nvalue = [248, 184]'),
#  Text(0.424681572020694, 0.7068965517241379, 'X[9] <= 18.5\ngini = 0.296\nsamples = 122\nvalue = [100, 22]'),
#  Text(0.4183886485341724, 0.6724137931034483, 'X[10] <= 2.5\ngini = 0.429\nsamples = 61\nvalue = [42, 19]'),
#  Text(0.41451608023477443, 0.6379310344827587, 'X[0] <= 43.0\ngini = 0.496\nsamples = 22\nvalue = [10, 12]'),
#  Text(0.4125797960850755, 0.603448275862069, 'X[9] <= 10.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.411611654010226, 0.5689655172413793, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.41354793815992497, 0.5689655172413793, 'X[11] <= 347.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.4125797960850755, 0.5344827586206896, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.41451608023477443, 0.5344827586206896, 'X[5] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.41354793815992497, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.41548422230962395, 0.5, 'X[2] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.41451608023477443, 0.46551724137931033, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4164523643844734, 0.46551724137931033, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4164523643844734, 0.603448275862069, 'X[9] <= 5.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.41548422230962395, 0.5689655172413793, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4174205064593229, 0.5689655172413793, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  ...]

# %% [markdown]
# # Random forest

# %%
#import the package
from sklearn.ensemble import RandomForestClassifier
rmf=RandomForestClassifier()

# %%
#fit the model
rmf=rmf.fit(X_train,Y_train)

# %%
#predict on test data
y_pred=rmf.predict(X_test)

# %%
#check the accuracy
accuracy_score(y_pred,Y_test)*100
# Out:
# 84.89101224246043
